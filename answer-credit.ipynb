# %%
# !pip install git+https://github.com/bhomass/conv_agent.git

# %%
from legal_corp.legal_agent import Legal_agent

# %%
legal_agent = Legal_agent()

# %%
corpus = legal_agent.get_corpus()

# %%
print(corpus)
# Out:
# <PAGE>   1
# EXHIBIT 10.1
# CREDIT AGREEMENT,
# dated as of October 1, 1997,
# among
# THE RUG BARN, INC.,
# HOME INNOVATIONS, INC.,
# DHA HOME, INC.
# AND R.A. BRIGGS AND COMPANY,
# AS BORROWERS,
# DECORATIVE HOME ACCENTS, INC.,
# DRAYMORE MFG. CORP.
# AND HOME INNOVATIONS, INC.,
# AS GUARANTORS,
# and
# THE LENDERS LISTED ON THE SIGNATURE PAGES HERETO,
# AS LENDERS
# <PAGE>   2
# Table of Contents
# <TABLE>
# <CAPTION>
# Page
# <S>                                                                                         <C>
# ARTICLE I   DEFINITIONS; CONSTRUCTION                                                         1
# 1.01. Certain Definitions                                                                 1
# 1.02. Construction                                                                       10
# 1.03. Accounting Principles                                                              11
# ...

# %%
question = "What does Congress mean?"

# %%
import time
start_time = time.time()

# %%
legal_agent.predict(question)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-3164c04199b8> in <module>()
# ----> 1 legal_agent.predict(question)
#
# /home/bruce/conv_agent/legal_corp/legal_agent.py in predict(self, question)
#      35     def predict(self, question):
#      36         prediction = self.predictor.predict(
# ---> 37             passage = self.corpus, question= question
#      38         )
#      39         return prediction["best_span_str"]
#
# /data/anaconda3/envs/allennlp/lib/python3.6/site-packages/allennlp_models/rc/predictors/bidaf.py in predict(self, question, passage)
#      42         "best_span_str" key.
#      43         """
# ---> 44         return self.predict_json({"passage": passage, "question": question})
#      45
#      46     @overrides
#
# ...

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 74.8086986541748 seconds ---
